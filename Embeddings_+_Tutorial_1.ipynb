# %%
# !pip install langchain==0.0.208 deeplake openai==0.27.8 tiktoken scikit-learn

# %%
import os
os.environ["OPENAI_API_KEY"] = "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"

# %%
import openai
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from langchain.embeddings import OpenAIEmbeddings
# Define the documents
documents = [
"The cat is on the mat.",
"There is a cat on the mat.",
"The dog is in the yard.",
"There is a dog in the yard.",
]
# Initialize the OpenAIEmbeddings instance
embeddings = OpenAIEmbeddings(model="text-embedding-ada-002")
# Generate embeddings for the documents
document_embeddings = embeddings.embed_documents(documents)
# Perform a similarity search for a given query
query = "A cat is sitting on a mat."
query_embedding = embeddings.embed_query(query)
# Calculate similarity scores
similarity_scores = cosine_similarity([query_embedding], document_embeddings)[0]
# Find the most similar document
most_similar_index = np.argmax(similarity_scores)
most_similar_document = documents[most_similar_index]
print(f"Most similar document to the query '{query}':")
print(most_similar_document)
# Out:
# Most similar document to the query 'A cat is sitting on a mat.':
# The cat is on the mat.

# %%
# !pip install sentence_transformers

# %%
# !pip uninstall -y sentence_transformers huggingface_hub
# !pip install huggingface_hub==0.16.4
# !pip install sentence_transformers

from langchain.llms import HuggingFacePipeline
from langchain.embeddings import HuggingFaceEmbeddings

model_name = "sentence-transformers/all-mpnet-base-v2"
model_kwargs = {'device': 'cpu'}
hf = HuggingFaceEmbeddings(model_name=model_name, model_kwargs=model_kwargs)
documents = ["Document 1", "Document 2", "Document 3"]
doc_embeddings = hf.embed_documents(documents)
# Out:
# Found existing installation: sentence-transformers 5.1.2
# Uninstalling sentence-transformers-5.1.2:
#   Successfully uninstalled sentence-transformers-5.1.2
# Found existing installation: huggingface-hub 0.36.0
# Uninstalling huggingface-hub-0.36.0:
#   Successfully uninstalled huggingface-hub-0.36.0
# ...
#   Using cached huggingface_hub-0.16.4-py3-none-any.whl.metadata (12 kB)
# ...
# Using cached huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# transformers 4.57.2 requires huggingface-hub<1.0,>=0.34.0, but you have huggingface-hub 0.16.4 which is incompatible.
# datasets 4.0.0 requires huggingface-hub>=0.24.0, but you have huggingface-hub 0.16.4 which is incompatible.
# accelerate 1.12.0 requires huggingface_hub>=0.21.0, but you have huggingface-hub 0.16.4 which is incompatible.
# ...

# %%
print("Document Embeddings:")
display(doc_embeddings)

if doc_embeddings:
    print(f"Type of one embedding: {type(doc_embeddings[0])}")
    print(f"Shape of one embedding: {doc_embeddings[0].shape if hasattr(doc_embeddings[0], 'shape') else 'N/A'}")
# Out:
# Document Embeddings:
# [[0.032010555267333984,
#   0.03800955414772034,
#   0.008137325756251812,
#   -0.05043879896402359,
#   -0.05071721971035004,
#   0.034477587789297104,
#   0.004744906909763813,
#   0.04772678390145302,
#   -0.05808492377400398,
#   -0.001789419329725206,
#   0.05319410562515259,
#   -0.023297064006328583,
#   0.041292011737823486,
#   0.0021979070734232664,
#   0.01498024258762598,
#   -0.059587594121694565,
#   0.03528381884098053,
#   -0.01269764918833971,
#   -0.044188693165779114,
#   -0.03513256832957268,
#   0.015517926774919033,
#   0.03705793246626854,
#   0.018301988020539284,
#   0.04435720667243004,
#   -0.007786773610860109,
#   -0.021996935829520226,
#   -0.01028862688690424,
#   0.03065389394760132,
#   -0.0794597864151001,
#   -0.03863370791077614,
#   0.012903307564556599,
#   0.04820918291807175,
#   0.05577970668673515,
#   -0.04650747776031494,
#   1.8786727196129505e-06,
#   -0.018225254490971565,
#   -0.018176428973674774,
# ...

# %%
# !pip install cohere

# %%
import cohere
from langchain.embeddings import CohereEmbeddings
# Initialize the CohereEmbeddings object
cohere = CohereEmbeddings(
  model="embed-multilingual-v2.0",
  cohere_api_key="CbjEmGRTV5xDsKH23SAZobiBAF9BOegHjBjoWjeu"
)
# Define a list of texts
texts = [
  "Hello from Cohere!",
  "!مرحبً ا م ن كوھير ",
  "Hallo von Cohere!",
  "Bonjour de Cohere!",
  "¡Hola desde Cohere!",
  "Olá do Cohere!",
  "Ciao da Cohere!",
  " 您好，来自 Cohere ！ ",
  " कोहेर◌े स◌े नम􀋑◌े !"
]
# Generate embeddings for the texts
document_embeddings = cohere.embed_documents(texts)
# Print the embeddings
for text, embedding in zip(texts, document_embeddings):
  print(f"Text: {text}")
  print(f"Embedding: {embedding[:5]}")
# Out:
# Text: Hello from Cohere!
# Embedding: [0.23388672, 0.50146484, -0.048828125, 0.14013672, -0.18017578]
# Text: !مرحبً ا م ن كوھير
# Embedding: [0.21289062, 0.19128418, -0.057617188, 0.1628418, -0.10241699]
# Text: Hallo von Cohere!
# Embedding: [0.10308838, 0.28344727, -0.0501709, 0.23718262, -0.07141113]
# Text: Bonjour de Cohere!
# Embedding: [0.15161133, 0.2824707, -0.057037354, 0.11730957, -0.044525146]
# Text: ¡Hola desde Cohere!
# Embedding: [0.25146484, 0.43139648, -0.085632324, 0.2467041, -0.11627197]
# Text: Olá do Cohere!
# Embedding: [0.18713379, 0.39086914, -0.045928955, 0.14575195, -0.11279297]
# Text: Ciao da Cohere!
# Embedding: [0.11602783, 0.43359375, -0.026184082, 0.14562988, 0.070495605]
# Text:  您好，来自 Cohere ！
# Embedding: [0.24621582, 0.30859375, -0.11175537, 0.26611328, -0.05130005]
# Text:  कोहेर◌े स◌े नम􀋑◌े !
# Embedding: [0.1328125, 0.5708008, -0.04449463, 0.0826416, 0.050567627]

# %%
# !pip install unstructured selenium

# %%
# !pip uninstall -y langchain langchain-core langchain-community langchain-openai langchain-text-splitters pydantic typing-extensions

# Install specific compatible versions
# !pip install pydantic==2.9.0 typing-extensions==4.12.0
# !pip install langchain-core==0.3.0 langchain-community==0.3.0 langchain-openai==0.2.0 langchain-text-splitters==0.3.0
# !pip install tiktoken beautifulsoup4 requests python-dotenv numpy scikit-learn
# Out:
# WARNING: Skipping langchain as it is not installed.
# WARNING: Skipping langchain-core as it is not installed.
# WARNING: Skipping langchain-community as it is not installed.
# WARNING: Skipping langchain-openai as it is not installed.
# WARNING: Skipping langchain-text-splitters as it is not installed.
# Found existing installation: pydantic 2.9.0
# Uninstalling pydantic-2.9.0:
#   Successfully uninstalled pydantic-2.9.0
# Found existing installation: typing_extensions 4.12.0
# Uninstalling typing_extensions-4.12.0:
#   Successfully uninstalled typing_extensions-4.12.0
# ...
#   Using cached pydantic-2.9.0-py3-none-any.whl.metadata (146 kB)
# ...
#   Using cached typing_extensions-4.12.0-py3-none-any.whl.metadata (3.0 kB)
# ...
# Using cached pydantic-2.9.0-py3-none-any.whl (434 kB)
# Using cached typing_extensions-4.12.0-py3-none-any.whl (37 kB)
# ...

# %%
from dotenv import load_dotenv
load_dotenv()

import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from langchain_community.document_loaders import WebBaseLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate, PromptTemplate

# %%
# we'll use information from the following articles
urls = ['https://beebom.com/what-is-nft-explained/',
  'https://beebom.com/how-delete-spotify-account/',
  'https://beebom.com/how-download-gif-twitter/',
  'https://beebom.com/how-use-chatgpt-linux-terminal/',
  'https://beebom.com/how-delete-spotify-account/',
  'https://beebom.com/how-save-instagram-story-with-music/',
  'https://beebom.com/how-install-pip-windows/',
  'https://beebom.com/how-check-disk-usage-linux/']

# %%
print("Loading documents from URLs...")
loader = WebBaseLoader(urls)
docs_not_splitted = loader.load()
print(f"✅ Loaded {len(docs_not_splitted)} documents")
# Out:
# Loading documents from URLs...
# ✅ Loaded 8 documents

# %%
print("\nSplitting documents into chunks...")
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=100
)
docs = text_splitter.split_documents(docs_not_splitted)
print(f"✅ Created {len(docs)} chunks")
# Out:
# Splitting documents into chunks...
# ✅ Created 142 chunks

# %%
import os

# Set it directly (replace XXXXX with your actual key)
os.environ["OPENAI_API_KEY"] = "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"

# Verify
print(f"✅ Key set: {os.environ['OPENAI_API_KEY'][:10]}...")
# Out:
# ✅ Key set: sk-proj-1C...

# %%
print("\nCreating embeddings using text-embedding-ada-002...")
embeddings_model = OpenAIEmbeddings(model="text-embedding-ada-002")

# Extract text content from documents
texts = [doc.page_content for doc in docs]

# Create embeddings for all chunks
embeddings = embeddings_model.embed_documents(texts)
print(f"✅ Created {len(embeddings)} embeddings")
# Out:
# Creating embeddings using text-embedding-ada-002...
# ✅ Created 142 embeddings

# %%
def similarity_search(query, k=3):
    """
    Retrieve the most similar chunks to a given query
    (replaces db.similarity_search from DeepLake)
    """
    # Create embedding for the query
    query_embedding = embeddings_model.embed_query(query)

    # Calculate cosine similarity
    similarities = cosine_similarity([query_embedding], embeddings)[0]

    # Get top k indices
    top_indices = np.argsort(similarities)[-k:][::-1]

    # Return top k documents
    return [docs[i] for i in top_indices]

# %%
print("\n" + "="*60)
print("Testing similarity search")
print("="*60)

# Let's see the top relevant documents to a specific query
query = "how to check disk usage in linux?"
retrieved_docs = similarity_search(query)

print(f"\nQuery: {query}")
print(f"\nTop result:\n{retrieved_docs[0].page_content[:500]}...")
# Out:
# ...
# Testing similarity search
# ...
#
# Query: how to check disk usage in linux?
#
# Top result:
# There may be times when you need to download some important files or transfer some photos to your Linux system, but face a problem of insufficient disk space. You head over to your file manager to delete the large files which you no longer require, but you have no clue which of them are occupying most of your disk space. In this article, we will show some easy methods to check disk usage in Linux from both the terminal and the GUI application.
# Check Disk Space Using the df Command
# In Linux, ther...

# %%
template = """You are an exceptional customer support chatbot that gently answer questions.

You know the following context information.

{chunks_formatted}

Answer to the following question from a customer. Use only information from the previous context information. Do not invent stuff.

Question: {query}

Answer:"""

prompt = PromptTemplate(
    input_variables=["chunks_formatted", "query"],
    template=template,
)

# %%
print("\n" + "="*60)
print("Generating answer with LLM")
print("="*60)

# User question
query = "How to check disk usage in linux?"

# Retrieve relevant chunks
retrieved_docs = similarity_search(query, k=3)
retrieved_chunks = [doc.page_content for doc in retrieved_docs]

# Format the prompt
chunks_formatted = "\n\n".join(retrieved_chunks)
prompt_formatted = prompt.format(chunks_formatted=chunks_formatted, query=query)

# Generate answer using ChatOpenAI (modern way)
llm = ChatOpenAI(model="gpt-3.5-turbo", temperature=0)
answer = llm.invoke(prompt_formatted)

print(f"\nQuestion: {query}")
print(f"\nAnswer: {answer.content}")
# Out:
# ...
# Generating answer with LLM
# ...
#
# Question: How to check disk usage in linux?
#
# Answer: To check disk usage in Linux, you can use the df command. The df command stands for "Disk Filesystem" and is a handy way to check the current disk usage and available disk space in Linux. You can use the syntax "df <options> <file_system>" to check disk usage. The options to use with the df command include various parameters to customize the output according to your requirements.

# %%
def ask_customer_support(question):
    """
    Complete pipeline for customer support Q&A
    """
    # Retrieve relevant chunks
    retrieved_docs = similarity_search(question, k=3)
    retrieved_chunks = [doc.page_content for doc in retrieved_docs]

    # Format the prompt
    chunks_formatted = "\n\n".join(retrieved_chunks)
    prompt_formatted = prompt.format(chunks_formatted=chunks_formatted, query=question)

    # Generate answer
    llm = ChatOpenAI(model="gpt-3.5-turbo", temperature=0)
    answer = llm.invoke(prompt_formatted)

    return answer.content

# ============================================================================
# TEST WITH MULTIPLE QUESTIONS
# ============================================================================

print("\n" + "="*60)
print("Testing Customer Support Chatbot")
print("="*60)

test_questions = [
    "How to check disk usage in linux?",
    "How do I delete my Spotify account?",
    "What is an NFT?",
    "How can I download GIFs from Twitter?",
    "How do I install pip on Windows?"
]

for question in test_questions:
    print(f"\n{'='*60}")
    print(f"Q: {question}")
    print(f"{'='*60}")

    answer = ask_customer_support(question)
    print(f"A: {answer}\n")

print("\n" + "="*60)
print("✅ Customer Support Chatbot Ready!")
print("="*60)
# Out:
# ...
# Testing Customer Support Chatbot
# ...
#
# ...
# Q: How to check disk usage in linux?
# ...
# A: To check disk usage in Linux, you can use the df command. The df command stands for "Disk Filesystem" and is a handy way to check the current disk usage and available disk space in Linux. You can use the syntax "df <options> <file_system>" to check disk usage. The options to use with the df command include various parameters to customize the output according to your requirements.
#
#
# ...
# Q: How do I delete my Spotify account?
# ...
# A: To delete your Spotify account, you will need to follow a few steps. If you are a premium user, you can go to the account settings and select the option to close your account. Spotify will then send a closure link to your email, which you must click on to confirm your decision. For free users, you can use a specific link on the account deletion support page to start the process. Make sure to follow the steps provided in the email from Spotify to complete the deletion process.
#
#
# ...

# %%
print("\n💬 Ask your own question:")
user_question = input("Your question: ")
answer = ask_customer_support(user_question)
print(f"\n🤖 Answer: {answer}")
# Out:
# 💬 Ask your own question:
# Your question: How do you cancel spotify
#
# 🤖 Answer: To cancel your Spotify subscription, open the Spotify app on your mobile device and tap on the "Settings" icon in the top-right corner. From the settings menu, select the option that says "Premium Plan". Next, scroll down and tap on the "See other plans" option, then select the "Change your plan" option. This will redirect you to the Spotify Subscription page where you can find the "Spotify Free" section. Tap the "Cancel Premium" button and confirm your choice to move your account to the free tier of Spotify.
